# %%
from tensorflow.keras.models import load_model
from collections import deque
import numpy as np
import argparse
import pickle
import cv2

# %%
model = load_model("sports_model.h5")
lb = pickle.loads(open("sports_labels.pkl", "rb").read())

# %%
def predict_frames(vid):
    
    mean = np.array([123.68, 116.779, 103.939][::1], dtype="float32")
    Q = deque(maxlen=128)
    
    # Get a sport video
    vs = cv2.VideoCapture(vid)

    iframe = 0
    grabbed = True
    
    print("File {}".format(vid))
    while grabbed:
        # read the next frame from the file
        (grabbed, frame) = vs.read()
        if not grabbed:
            break

        output = frame.copy()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (224, 224)).astype("float32")
        frame -= mean

        preds = model.predict(np.expand_dims(frame, axis=0))[0]
        ipred = np.argmax(preds)
        label = lb.classes_[ipred]
        
        Q.append(preds)
        smooth = np.array(Q).mean(axis=0)
        ipred = np.argmax(smooth)
        smthLbl = lb.classes_[ipred]
        
        print("frame{} predicts {} smoothed this is {}".format(iframe, label, smthLbl))
 
        
        iframe += 1

# %%
predict_frames(vid = "test/data/example_clips/lifting.mp4")
# Out:
# File test/data/example_clips/lifting.mp4
# frame0 predicts weight_lifting smoothed this is weight_lifting
# frame1 predicts weight_lifting smoothed this is weight_lifting
# frame2 predicts weight_lifting smoothed this is weight_lifting
# frame3 predicts weight_lifting smoothed this is weight_lifting
# frame4 predicts weight_lifting smoothed this is weight_lifting
# frame5 predicts weight_lifting smoothed this is weight_lifting
# frame6 predicts weight_lifting smoothed this is weight_lifting
# frame7 predicts weight_lifting smoothed this is weight_lifting
# frame8 predicts weight_lifting smoothed this is weight_lifting
# frame9 predicts weight_lifting smoothed this is weight_lifting
# frame10 predicts weight_lifting smoothed this is weight_lifting
# frame11 predicts weight_lifting smoothed this is weight_lifting
# frame12 predicts weight_lifting smoothed this is weight_lifting
# frame13 predicts weight_lifting smoothed this is weight_lifting
# frame14 predicts weight_lifting smoothed this is weight_lifting
# frame15 predicts weight_lifting smoothed this is weight_lifting
# frame16 predicts weight_lifting smoothed this is weight_lifting
# frame17 predicts weight_lifting smoothed this is weight_lifting
# frame18 predicts weight_lifting smoothed this is weight_lifting
# frame19 predicts weight_lifting smoothed this is weight_lifting
# frame20 predicts weight_lifting smoothed this is weight_lifting
# frame21 predicts weight_lifting smoothed this is weight_lifting
# frame22 predicts weight_lifting smoothed this is weight_lifting
# frame23 predicts weight_lifting smoothed this is weight_lifting
# frame24 predicts weight_lifting smoothed this is weight_lifting
# frame25 predicts weight_lifting smoothed this is weight_lifting
# frame26 predicts weight_lifting smoothed this is weight_lifting
# frame27 predicts weight_lifting smoothed this is weight_lifting
# frame28 predicts weight_lifting smoothed this is weight_lifting
# frame29 predicts weight_lifting smoothed this is weight_lifting
# frame30 predicts weight_lifting smoothed this is weight_lifting
# frame31 predicts weight_lifting smoothed this is weight_lifting
# frame32 predicts weight_lifting smoothed this is weight_lifting
# frame33 predicts weight_lifting smoothed this is weight_lifting
# frame34 predicts weight_lifting smoothed this is weight_lifting
# frame35 predicts weight_lifting smoothed this is weight_lifting
# frame36 predicts weight_lifting smoothed this is weight_lifting
# frame37 predicts weight_lifting smoothed this is weight_lifting
# frame38 predicts weight_lifting smoothed this is weight_lifting
# frame39 predicts weight_lifting smoothed this is weight_lifting
# frame40 predicts weight_lifting smoothed this is weight_lifting
# frame41 predicts weight_lifting smoothed this is weight_lifting
# frame42 predicts weight_lifting smoothed this is weight_lifting
# frame43 predicts weight_lifting smoothed this is weight_lifting
# frame44 predicts weight_lifting smoothed this is weight_lifting
# frame45 predicts weight_lifting smoothed this is weight_lifting
# frame46 predicts weight_lifting smoothed this is weight_lifting
# frame47 predicts weight_lifting smoothed this is weight_lifting
# frame48 predicts weight_lifting smoothed this is weight_lifting
# frame49 predicts weight_lifting smoothed this is weight_lifting
# frame50 predicts weight_lifting smoothed this is weight_lifting
# frame51 predicts weight_lifting smoothed this is weight_lifting
# frame52 predicts weight_lifting smoothed this is weight_lifting
# frame53 predicts table_tennis smoothed this is weight_lifting
# frame54 predicts weight_lifting smoothed this is weight_lifting
# frame55 predicts weight_lifting smoothed this is weight_lifting
# frame56 predicts weight_lifting smoothed this is weight_lifting
# frame57 predicts table_tennis smoothed this is weight_lifting
# frame58 predicts weight_lifting smoothed this is weight_lifting
# frame59 predicts weight_lifting smoothed this is weight_lifting
# frame60 predicts weight_lifting smoothed this is weight_lifting
# frame61 predicts weight_lifting smoothed this is weight_lifting
# frame62 predicts weight_lifting smoothed this is weight_lifting
# frame63 predicts weight_lifting smoothed this is weight_lifting
# frame64 predicts weight_lifting smoothed this is weight_lifting
# frame65 predicts weight_lifting smoothed this is weight_lifting
# frame66 predicts weight_lifting smoothed this is weight_lifting
# frame67 predicts weight_lifting smoothed this is weight_lifting
# frame68 predicts weight_lifting smoothed this is weight_lifting
# frame69 predicts weight_lifting smoothed this is weight_lifting
# frame70 predicts weight_lifting smoothed this is weight_lifting
# frame71 predicts weight_lifting smoothed this is weight_lifting
# frame72 predicts weight_lifting smoothed this is weight_lifting
# frame73 predicts table_tennis smoothed this is weight_lifting
# frame74 predicts table_tennis smoothed this is weight_lifting
# frame75 predicts weight_lifting smoothed this is weight_lifting
# frame76 predicts weight_lifting smoothed this is weight_lifting
# frame77 predicts weight_lifting smoothed this is weight_lifting
# frame78 predicts weight_lifting smoothed this is weight_lifting
# frame79 predicts weight_lifting smoothed this is weight_lifting
# frame80 predicts weight_lifting smoothed this is weight_lifting
# frame81 predicts weight_lifting smoothed this is weight_lifting
# frame82 predicts weight_lifting smoothed this is weight_lifting
# frame83 predicts weight_lifting smoothed this is weight_lifting
# frame84 predicts weight_lifting smoothed this is weight_lifting
# frame85 predicts table_tennis smoothed this is weight_lifting
# frame86 predicts table_tennis smoothed this is weight_lifting
# frame87 predicts table_tennis smoothed this is weight_lifting
# frame88 predicts weight_lifting smoothed this is weight_lifting
# frame89 predicts weight_lifting smoothed this is weight_lifting
# frame90 predicts weight_lifting smoothed this is weight_lifting
# frame91 predicts weight_lifting smoothed this is weight_lifting
# frame92 predicts table_tennis smoothed this is weight_lifting
# frame93 predicts table_tennis smoothed this is weight_lifting
# frame94 predicts table_tennis smoothed this is weight_lifting
# frame95 predicts table_tennis smoothed this is weight_lifting
# frame96 predicts table_tennis smoothed this is weight_lifting
# frame97 predicts weight_lifting smoothed this is weight_lifting
# frame98 predicts weight_lifting smoothed this is weight_lifting
# frame99 predicts weight_lifting smoothed this is weight_lifting
# frame100 predicts weight_lifting smoothed this is weight_lifting
# frame101 predicts weight_lifting smoothed this is weight_lifting
# frame102 predicts weight_lifting smoothed this is weight_lifting
# frame103 predicts weight_lifting smoothed this is weight_lifting
# frame104 predicts weight_lifting smoothed this is weight_lifting
# frame105 predicts weight_lifting smoothed this is weight_lifting
# frame106 predicts weight_lifting smoothed this is weight_lifting
# frame107 predicts weight_lifting smoothed this is weight_lifting
# frame108 predicts weight_lifting smoothed this is weight_lifting
# frame109 predicts weight_lifting smoothed this is weight_lifting
# frame110 predicts weight_lifting smoothed this is weight_lifting
# frame111 predicts weight_lifting smoothed this is weight_lifting
# frame112 predicts weight_lifting smoothed this is weight_lifting
# frame113 predicts weight_lifting smoothed this is weight_lifting
# frame114 predicts weight_lifting smoothed this is weight_lifting
# frame115 predicts weight_lifting smoothed this is weight_lifting
# frame116 predicts weight_lifting smoothed this is weight_lifting
# frame117 predicts weight_lifting smoothed this is weight_lifting
# frame118 predicts weight_lifting smoothed this is weight_lifting
# frame119 predicts weight_lifting smoothed this is weight_lifting
# frame120 predicts weight_lifting smoothed this is weight_lifting
# frame121 predicts weight_lifting smoothed this is weight_lifting
# frame122 predicts weight_lifting smoothed this is weight_lifting
# frame123 predicts weight_lifting smoothed this is weight_lifting
# frame124 predicts weight_lifting smoothed this is weight_lifting
# frame125 predicts weight_lifting smoothed this is weight_lifting
# frame126 predicts weight_lifting smoothed this is weight_lifting
# frame127 predicts weight_lifting smoothed this is weight_lifting
# frame128 predicts weight_lifting smoothed this is weight_lifting
# frame129 predicts weight_lifting smoothed this is weight_lifting
# frame130 predicts weight_lifting smoothed this is weight_lifting
# frame131 predicts weight_lifting smoothed this is weight_lifting
# frame132 predicts weight_lifting smoothed this is weight_lifting
# frame133 predicts weight_lifting smoothed this is weight_lifting
# frame134 predicts weight_lifting smoothed this is weight_lifting
# frame135 predicts weight_lifting smoothed this is weight_lifting
# frame136 predicts weight_lifting smoothed this is weight_lifting
# frame137 predicts weight_lifting smoothed this is weight_lifting
# frame138 predicts weight_lifting smoothed this is weight_lifting
# frame139 predicts weight_lifting smoothed this is weight_lifting
# frame140 predicts weight_lifting smoothed this is weight_lifting
# frame141 predicts weight_lifting smoothed this is weight_lifting
# frame142 predicts weight_lifting smoothed this is weight_lifting
# frame143 predicts weight_lifting smoothed this is weight_lifting
# frame144 predicts weight_lifting smoothed this is weight_lifting
# frame145 predicts weight_lifting smoothed this is weight_lifting
# frame146 predicts weight_lifting smoothed this is weight_lifting
# frame147 predicts weight_lifting smoothed this is weight_lifting
# frame148 predicts weight_lifting smoothed this is weight_lifting
# frame149 predicts weight_lifting smoothed this is weight_lifting
# frame150 predicts weight_lifting smoothed this is weight_lifting
# frame151 predicts weight_lifting smoothed this is weight_lifting
# frame152 predicts weight_lifting smoothed this is weight_lifting
# frame153 predicts weight_lifting smoothed this is weight_lifting
# frame154 predicts weight_lifting smoothed this is weight_lifting
# frame155 predicts weight_lifting smoothed this is weight_lifting
# frame156 predicts weight_lifting smoothed this is weight_lifting
# frame157 predicts weight_lifting smoothed this is weight_lifting
# frame158 predicts weight_lifting smoothed this is weight_lifting
# frame159 predicts weight_lifting smoothed this is weight_lifting
# frame160 predicts weight_lifting smoothed this is weight_lifting
# frame161 predicts weight_lifting smoothed this is weight_lifting
# frame162 predicts weight_lifting smoothed this is weight_lifting
# frame163 predicts weight_lifting smoothed this is weight_lifting
# frame164 predicts weight_lifting smoothed this is weight_lifting
# frame165 predicts weight_lifting smoothed this is weight_lifting
# frame166 predicts weight_lifting smoothed this is weight_lifting
# frame167 predicts weight_lifting smoothed this is weight_lifting
# frame168 predicts weight_lifting smoothed this is weight_lifting
# frame169 predicts weight_lifting smoothed this is weight_lifting
# frame170 predicts weight_lifting smoothed this is weight_lifting
# frame171 predicts weight_lifting smoothed this is weight_lifting
# frame172 predicts weight_lifting smoothed this is weight_lifting
# frame173 predicts weight_lifting smoothed this is weight_lifting
# frame174 predicts weight_lifting smoothed this is weight_lifting
# frame175 predicts weight_lifting smoothed this is weight_lifting
# frame176 predicts weight_lifting smoothed this is weight_lifting
# frame177 predicts weight_lifting smoothed this is weight_lifting
# frame178 predicts weight_lifting smoothed this is weight_lifting
# frame179 predicts weight_lifting smoothed this is weight_lifting
# frame180 predicts weight_lifting smoothed this is weight_lifting
# frame181 predicts weight_lifting smoothed this is weight_lifting
# frame182 predicts weight_lifting smoothed this is weight_lifting
# frame183 predicts weight_lifting smoothed this is weight_lifting
# frame184 predicts weight_lifting smoothed this is weight_lifting
# frame185 predicts weight_lifting smoothed this is weight_lifting
# frame186 predicts weight_lifting smoothed this is weight_lifting
# frame187 predicts weight_lifting smoothed this is weight_lifting
# frame188 predicts weight_lifting smoothed this is weight_lifting
# frame189 predicts weight_lifting smoothed this is weight_lifting
# frame190 predicts weight_lifting smoothed this is weight_lifting
# frame191 predicts weight_lifting smoothed this is weight_lifting
# frame192 predicts weight_lifting smoothed this is weight_lifting
# frame193 predicts weight_lifting smoothed this is weight_lifting
# frame194 predicts weight_lifting smoothed this is weight_lifting
# frame195 predicts weight_lifting smoothed this is weight_lifting
# frame196 predicts weight_lifting smoothed this is weight_lifting
# frame197 predicts weight_lifting smoothed this is weight_lifting
# frame198 predicts weight_lifting smoothed this is weight_lifting
# frame199 predicts weight_lifting smoothed this is weight_lifting
# frame200 predicts weight_lifting smoothed this is weight_lifting
# frame201 predicts weight_lifting smoothed this is weight_lifting
# frame202 predicts weight_lifting smoothed this is weight_lifting
# frame203 predicts weight_lifting smoothed this is weight_lifting
# frame204 predicts weight_lifting smoothed this is weight_lifting
# frame205 predicts weight_lifting smoothed this is weight_lifting
# frame206 predicts weight_lifting smoothed this is weight_lifting
# frame207 predicts weight_lifting smoothed this is weight_lifting
# frame208 predicts weight_lifting smoothed this is weight_lifting
# frame209 predicts weight_lifting smoothed this is weight_lifting
# frame210 predicts weight_lifting smoothed this is weight_lifting
# frame211 predicts weight_lifting smoothed this is weight_lifting
# frame212 predicts weight_lifting smoothed this is weight_lifting
# frame213 predicts weight_lifting smoothed this is weight_lifting
# frame214 predicts weight_lifting smoothed this is weight_lifting
# frame215 predicts weight_lifting smoothed this is weight_lifting
# frame216 predicts weight_lifting smoothed this is weight_lifting
# frame217 predicts weight_lifting smoothed this is weight_lifting
# frame218 predicts weight_lifting smoothed this is weight_lifting
# frame219 predicts weight_lifting smoothed this is weight_lifting
# frame220 predicts badminton smoothed this is weight_lifting
# frame221 predicts badminton smoothed this is weight_lifting
# frame222 predicts badminton smoothed this is weight_lifting
# frame223 predicts gymnastics smoothed this is weight_lifting
# frame224 predicts gymnastics smoothed this is weight_lifting
# frame225 predicts weight_lifting smoothed this is weight_lifting
# frame226 predicts fencing smoothed this is weight_lifting
# frame227 predicts fencing smoothed this is weight_lifting
# frame228 predicts gymnastics smoothed this is weight_lifting
# frame229 predicts table_tennis smoothed this is weight_lifting
# frame230 predicts weight_lifting smoothed this is weight_lifting
# frame231 predicts weight_lifting smoothed this is weight_lifting
# frame232 predicts weight_lifting smoothed this is weight_lifting
# frame233 predicts weight_lifting smoothed this is weight_lifting
# frame234 predicts weight_lifting smoothed this is weight_lifting
# frame235 predicts weight_lifting smoothed this is weight_lifting
# frame236 predicts weight_lifting smoothed this is weight_lifting
# frame237 predicts weight_lifting smoothed this is weight_lifting
# frame238 predicts weight_lifting smoothed this is weight_lifting
# frame239 predicts weight_lifting smoothed this is weight_lifting
# frame240 predicts weight_lifting smoothed this is weight_lifting
# frame241 predicts weight_lifting smoothed this is weight_lifting
# frame242 predicts weight_lifting smoothed this is weight_lifting
# frame243 predicts table_tennis smoothed this is weight_lifting
# frame244 predicts weight_lifting smoothed this is weight_lifting
# frame245 predicts fencing smoothed this is weight_lifting
# frame246 predicts gymnastics smoothed this is weight_lifting
# frame247 predicts gymnastics smoothed this is weight_lifting
# frame248 predicts weight_lifting smoothed this is weight_lifting
# frame249 predicts weight_lifting smoothed this is weight_lifting
# frame250 predicts weight_lifting smoothed this is weight_lifting
# frame251 predicts weight_lifting smoothed this is weight_lifting
# frame252 predicts weight_lifting smoothed this is weight_lifting
# frame253 predicts weight_lifting smoothed this is weight_lifting
# frame254 predicts weight_lifting smoothed this is weight_lifting
# frame255 predicts weight_lifting smoothed this is weight_lifting
# frame256 predicts fencing smoothed this is weight_lifting
# frame257 predicts fencing smoothed this is weight_lifting
# frame258 predicts weight_lifting smoothed this is weight_lifting
# frame259 predicts weight_lifting smoothed this is weight_lifting
# frame260 predicts weight_lifting smoothed this is weight_lifting
# frame261 predicts weight_lifting smoothed this is weight_lifting
# frame262 predicts weight_lifting smoothed this is weight_lifting
# frame263 predicts weight_lifting smoothed this is weight_lifting
# frame264 predicts weight_lifting smoothed this is weight_lifting
# frame265 predicts weight_lifting smoothed this is weight_lifting
# frame266 predicts weight_lifting smoothed this is weight_lifting
# frame267 predicts weight_lifting smoothed this is weight_lifting
# frame268 predicts weight_lifting smoothed this is weight_lifting
# frame269 predicts weight_lifting smoothed this is weight_lifting
# frame270 predicts weight_lifting smoothed this is weight_lifting
# frame271 predicts weight_lifting smoothed this is weight_lifting
# frame272 predicts weight_lifting smoothed this is weight_lifting
# frame273 predicts weight_lifting smoothed this is weight_lifting
# frame274 predicts weight_lifting smoothed this is weight_lifting

# %%
predict_frames(vid = "test/data/example_clips/soccer.mp4")
# Out:
# File test/data/example_clips/soccer.mp4
# frame0 predicts football smoothed this is football
# frame1 predicts football smoothed this is football
# frame2 predicts football smoothed this is football
# frame3 predicts football smoothed this is football
# frame4 predicts football smoothed this is football
# frame5 predicts football smoothed this is football
# frame6 predicts football smoothed this is football
# frame7 predicts football smoothed this is football
# frame8 predicts football smoothed this is football
# frame9 predicts football smoothed this is football
# frame10 predicts football smoothed this is football
# frame11 predicts football smoothed this is football
# frame12 predicts football smoothed this is football
# frame13 predicts football smoothed this is football
# frame14 predicts football smoothed this is football
# frame15 predicts football smoothed this is football
# frame16 predicts football smoothed this is football
# frame17 predicts football smoothed this is football
# frame18 predicts football smoothed this is football
# frame19 predicts football smoothed this is football
# frame20 predicts football smoothed this is football
# frame21 predicts football smoothed this is football
# frame22 predicts football smoothed this is football
# frame23 predicts football smoothed this is football
# frame24 predicts football smoothed this is football
# frame25 predicts football smoothed this is football
# frame26 predicts football smoothed this is football
# frame27 predicts football smoothed this is football
# frame28 predicts football smoothed this is football
# frame29 predicts football smoothed this is football
# frame30 predicts football smoothed this is football
# frame31 predicts football smoothed this is football
# frame32 predicts football smoothed this is football
# frame33 predicts football smoothed this is football
# frame34 predicts football smoothed this is football
# frame35 predicts football smoothed this is football
# frame36 predicts football smoothed this is football
# frame37 predicts football smoothed this is football
# frame38 predicts football smoothed this is football
# frame39 predicts football smoothed this is football
# frame40 predicts football smoothed this is football
# frame41 predicts football smoothed this is football
# frame42 predicts football smoothed this is football
# frame43 predicts football smoothed this is football
# frame44 predicts football smoothed this is football
# frame45 predicts football smoothed this is football
# frame46 predicts football smoothed this is football
# frame47 predicts football smoothed this is football
# frame48 predicts football smoothed this is football
# frame49 predicts football smoothed this is football
# frame50 predicts football smoothed this is football
# frame51 predicts football smoothed this is football
# frame52 predicts football smoothed this is football
# frame53 predicts football smoothed this is football
# frame54 predicts football smoothed this is football
# frame55 predicts football smoothed this is football
# frame56 predicts football smoothed this is football
# frame57 predicts football smoothed this is football
# frame58 predicts football smoothed this is football
# frame59 predicts football smoothed this is football
# frame60 predicts football smoothed this is football
# frame61 predicts football smoothed this is football
# frame62 predicts football smoothed this is football
# frame63 predicts football smoothed this is football
# frame64 predicts football smoothed this is football
# frame65 predicts football smoothed this is football
# frame66 predicts football smoothed this is football
# frame67 predicts football smoothed this is football
# frame68 predicts football smoothed this is football
# frame69 predicts football smoothed this is football
# frame70 predicts football smoothed this is football
# frame71 predicts football smoothed this is football
# frame72 predicts football smoothed this is football
# frame73 predicts football smoothed this is football
# frame74 predicts football smoothed this is football
# frame75 predicts football smoothed this is football
# frame76 predicts football smoothed this is football
# frame77 predicts football smoothed this is football
# frame78 predicts football smoothed this is football
# frame79 predicts football smoothed this is football
# frame80 predicts football smoothed this is football
# frame81 predicts football smoothed this is football
# frame82 predicts football smoothed this is football
# frame83 predicts football smoothed this is football
# frame84 predicts football smoothed this is football
# frame85 predicts football smoothed this is football
# frame86 predicts football smoothed this is football
# frame87 predicts football smoothed this is football
# frame88 predicts football smoothed this is football
# frame89 predicts football smoothed this is football
# frame90 predicts football smoothed this is football
# frame91 predicts football smoothed this is football
# frame92 predicts football smoothed this is football
# frame93 predicts football smoothed this is football
# frame94 predicts football smoothed this is football
# frame95 predicts football smoothed this is football
# frame96 predicts football smoothed this is football
# frame97 predicts football smoothed this is football
# frame98 predicts football smoothed this is football
# frame99 predicts football smoothed this is football
# frame100 predicts football smoothed this is football
# frame101 predicts football smoothed this is football
# frame102 predicts football smoothed this is football
# frame103 predicts football smoothed this is football
# frame104 predicts football smoothed this is football
# frame105 predicts football smoothed this is football
# frame106 predicts football smoothed this is football
# frame107 predicts football smoothed this is football
# frame108 predicts football smoothed this is football
# frame109 predicts football smoothed this is football
# frame110 predicts football smoothed this is football
# frame111 predicts football smoothed this is football
# frame112 predicts football smoothed this is football
# frame113 predicts football smoothed this is football
# frame114 predicts football smoothed this is football
# frame115 predicts football smoothed this is football
# frame116 predicts football smoothed this is football
# frame117 predicts football smoothed this is football
# frame118 predicts football smoothed this is football
# frame119 predicts football smoothed this is football
# frame120 predicts football smoothed this is football
# frame121 predicts football smoothed this is football
# frame122 predicts football smoothed this is football
# frame123 predicts football smoothed this is football
# frame124 predicts football smoothed this is football
# frame125 predicts football smoothed this is football
# frame126 predicts football smoothed this is football
# frame127 predicts football smoothed this is football
# frame128 predicts football smoothed this is football
# frame129 predicts football smoothed this is football
# frame130 predicts football smoothed this is football
# frame131 predicts football smoothed this is football
# frame132 predicts football smoothed this is football
# frame133 predicts football smoothed this is football
# frame134 predicts football smoothed this is football
# frame135 predicts football smoothed this is football
# frame136 predicts football smoothed this is football
# frame137 predicts football smoothed this is football

# %%
predict_frames(vid = "test/data/example_clips/tennis.mp4")
# Out:
# File test/data/example_clips/tennis.mp4
# frame0 predicts tennis smoothed this is tennis
# frame1 predicts tennis smoothed this is tennis
# frame2 predicts tennis smoothed this is tennis
# frame3 predicts tennis smoothed this is tennis
# frame4 predicts tennis smoothed this is tennis
# frame5 predicts tennis smoothed this is tennis
# frame6 predicts tennis smoothed this is tennis
# frame7 predicts tennis smoothed this is tennis
# frame8 predicts tennis smoothed this is tennis
# frame9 predicts tennis smoothed this is tennis
# frame10 predicts tennis smoothed this is tennis
# frame11 predicts tennis smoothed this is tennis
# frame12 predicts tennis smoothed this is tennis
# frame13 predicts tennis smoothed this is tennis
# frame14 predicts tennis smoothed this is tennis
# frame15 predicts tennis smoothed this is tennis
# frame16 predicts tennis smoothed this is tennis
# frame17 predicts tennis smoothed this is tennis
# frame18 predicts tennis smoothed this is tennis
# frame19 predicts tennis smoothed this is tennis
# frame20 predicts tennis smoothed this is tennis
# frame21 predicts tennis smoothed this is tennis
# frame22 predicts tennis smoothed this is tennis
# frame23 predicts tennis smoothed this is tennis
# frame24 predicts tennis smoothed this is tennis
# frame25 predicts tennis smoothed this is tennis
# frame26 predicts tennis smoothed this is tennis
# frame27 predicts tennis smoothed this is tennis
# frame28 predicts tennis smoothed this is tennis
# frame29 predicts tennis smoothed this is tennis
# frame30 predicts tennis smoothed this is tennis
# frame31 predicts tennis smoothed this is tennis
# frame32 predicts tennis smoothed this is tennis
# frame33 predicts tennis smoothed this is tennis
# frame34 predicts tennis smoothed this is tennis
# frame35 predicts tennis smoothed this is tennis
# frame36 predicts tennis smoothed this is tennis
# frame37 predicts tennis smoothed this is tennis
# frame38 predicts tennis smoothed this is tennis
# frame39 predicts tennis smoothed this is tennis
# frame40 predicts tennis smoothed this is tennis
# frame41 predicts tennis smoothed this is tennis
# frame42 predicts tennis smoothed this is tennis
# frame43 predicts tennis smoothed this is tennis
# frame44 predicts tennis smoothed this is tennis
# frame45 predicts tennis smoothed this is tennis
# frame46 predicts tennis smoothed this is tennis
# frame47 predicts tennis smoothed this is tennis
# frame48 predicts tennis smoothed this is tennis
# frame49 predicts tennis smoothed this is tennis
# frame50 predicts tennis smoothed this is tennis
# frame51 predicts tennis smoothed this is tennis
# frame52 predicts tennis smoothed this is tennis
# frame53 predicts tennis smoothed this is tennis
# frame54 predicts tennis smoothed this is tennis
# frame55 predicts tennis smoothed this is tennis
# frame56 predicts tennis smoothed this is tennis
# frame57 predicts tennis smoothed this is tennis
# frame58 predicts tennis smoothed this is tennis
# frame59 predicts tennis smoothed this is tennis
# frame60 predicts tennis smoothed this is tennis
# frame61 predicts tennis smoothed this is tennis
# frame62 predicts tennis smoothed this is tennis
# frame63 predicts tennis smoothed this is tennis
# frame64 predicts tennis smoothed this is tennis
# frame65 predicts tennis smoothed this is tennis
# frame66 predicts tennis smoothed this is tennis
# frame67 predicts tennis smoothed this is tennis
# frame68 predicts tennis smoothed this is tennis
# frame69 predicts tennis smoothed this is tennis
# frame70 predicts tennis smoothed this is tennis
# frame71 predicts tennis smoothed this is tennis
# frame72 predicts tennis smoothed this is tennis
# frame73 predicts tennis smoothed this is tennis
# frame74 predicts tennis smoothed this is tennis
# frame75 predicts tennis smoothed this is tennis
# frame76 predicts tennis smoothed this is tennis
# frame77 predicts tennis smoothed this is tennis
# frame78 predicts tennis smoothed this is tennis
# frame79 predicts tennis smoothed this is tennis
# frame80 predicts tennis smoothed this is tennis
# frame81 predicts tennis smoothed this is tennis
# frame82 predicts tennis smoothed this is tennis
# frame83 predicts tennis smoothed this is tennis
# frame84 predicts tennis smoothed this is tennis
# frame85 predicts tennis smoothed this is tennis
# frame86 predicts tennis smoothed this is tennis
# frame87 predicts tennis smoothed this is tennis
# frame88 predicts tennis smoothed this is tennis
# frame89 predicts tennis smoothed this is tennis
# frame90 predicts tennis smoothed this is tennis
# frame91 predicts tennis smoothed this is tennis
# frame92 predicts tennis smoothed this is tennis
# frame93 predicts tennis smoothed this is tennis
# frame94 predicts tennis smoothed this is tennis
# frame95 predicts tennis smoothed this is tennis
# frame96 predicts tennis smoothed this is tennis
# frame97 predicts tennis smoothed this is tennis
# frame98 predicts tennis smoothed this is tennis
# frame99 predicts tennis smoothed this is tennis
# frame100 predicts tennis smoothed this is tennis
# frame101 predicts tennis smoothed this is tennis
# frame102 predicts tennis smoothed this is tennis
# frame103 predicts tennis smoothed this is tennis
# frame104 predicts tennis smoothed this is tennis
# frame105 predicts tennis smoothed this is tennis
# frame106 predicts tennis smoothed this is tennis
# frame107 predicts tennis smoothed this is tennis
# frame108 predicts tennis smoothed this is tennis
# frame109 predicts tennis smoothed this is tennis
# frame110 predicts tennis smoothed this is tennis
# frame111 predicts tennis smoothed this is tennis
# frame112 predicts tennis smoothed this is tennis
# frame113 predicts tennis smoothed this is tennis
# frame114 predicts tennis smoothed this is tennis
# frame115 predicts tennis smoothed this is tennis
# frame116 predicts tennis smoothed this is tennis
# frame117 predicts tennis smoothed this is tennis
# frame118 predicts tennis smoothed this is tennis
# frame119 predicts tennis smoothed this is tennis
# frame120 predicts tennis smoothed this is tennis
# frame121 predicts tennis smoothed this is tennis
# frame122 predicts tennis smoothed this is tennis
# frame123 predicts tennis smoothed this is tennis
# frame124 predicts tennis smoothed this is tennis
# frame125 predicts tennis smoothed this is tennis
# frame126 predicts tennis smoothed this is tennis
# frame127 predicts tennis smoothed this is tennis
# frame128 predicts tennis smoothed this is tennis
# frame129 predicts tennis smoothed this is tennis
# frame130 predicts tennis smoothed this is tennis
# frame131 predicts tennis smoothed this is tennis
# frame132 predicts tennis smoothed this is tennis
# frame133 predicts tennis smoothed this is tennis
# frame134 predicts tennis smoothed this is tennis
# frame135 predicts tennis smoothed this is tennis
# frame136 predicts tennis smoothed this is tennis
# frame137 predicts tennis smoothed this is tennis
# frame138 predicts tennis smoothed this is tennis
# frame139 predicts tennis smoothed this is tennis
# frame140 predicts tennis smoothed this is tennis
# frame141 predicts tennis smoothed this is tennis
# frame142 predicts tennis smoothed this is tennis
# frame143 predicts tennis smoothed this is tennis
# frame144 predicts tennis smoothed this is tennis
# frame145 predicts tennis smoothed this is tennis
# frame146 predicts tennis smoothed this is tennis
# frame147 predicts tennis smoothed this is tennis
# frame148 predicts tennis smoothed this is tennis
# frame149 predicts tennis smoothed this is tennis
# frame150 predicts tennis smoothed this is tennis
# frame151 predicts tennis smoothed this is tennis
# frame152 predicts tennis smoothed this is tennis
# frame153 predicts tennis smoothed this is tennis
# frame154 predicts tennis smoothed this is tennis
# frame155 predicts tennis smoothed this is tennis
# frame156 predicts tennis smoothed this is tennis
# frame157 predicts tennis smoothed this is tennis
# frame158 predicts tennis smoothed this is tennis
# frame159 predicts tennis smoothed this is tennis
# frame160 predicts tennis smoothed this is tennis
# frame161 predicts tennis smoothed this is tennis
# frame162 predicts tennis smoothed this is tennis
# frame163 predicts tennis smoothed this is tennis
# frame164 predicts tennis smoothed this is tennis
# frame165 predicts tennis smoothed this is tennis
# frame166 predicts tennis smoothed this is tennis
# frame167 predicts tennis smoothed this is tennis
# frame168 predicts tennis smoothed this is tennis
# frame169 predicts tennis smoothed this is tennis
# frame170 predicts tennis smoothed this is tennis
# frame171 predicts tennis smoothed this is tennis
# frame172 predicts tennis smoothed this is tennis
# frame173 predicts tennis smoothed this is tennis
# frame174 predicts tennis smoothed this is tennis
# frame175 predicts tennis smoothed this is tennis
# frame176 predicts tennis smoothed this is tennis
# frame177 predicts tennis smoothed this is tennis
# frame178 predicts tennis smoothed this is tennis
# frame179 predicts tennis smoothed this is tennis
# frame180 predicts tennis smoothed this is tennis
# frame181 predicts tennis smoothed this is tennis
# frame182 predicts tennis smoothed this is tennis
# frame183 predicts tennis smoothed this is tennis
# frame184 predicts tennis smoothed this is tennis
# frame185 predicts tennis smoothed this is tennis
# frame186 predicts tennis smoothed this is tennis
# frame187 predicts tennis smoothed this is tennis
# frame188 predicts tennis smoothed this is tennis
# frame189 predicts tennis smoothed this is tennis
# frame190 predicts tennis smoothed this is tennis
# frame191 predicts tennis smoothed this is tennis
# frame192 predicts tennis smoothed this is tennis
# frame193 predicts tennis smoothed this is tennis
# frame194 predicts tennis smoothed this is tennis
# frame195 predicts tennis smoothed this is tennis
# frame196 predicts tennis smoothed this is tennis
# frame197 predicts tennis smoothed this is tennis
# frame198 predicts tennis smoothed this is tennis
# frame199 predicts tennis smoothed this is tennis
# frame200 predicts tennis smoothed this is tennis
# frame201 predicts tennis smoothed this is tennis
# frame202 predicts tennis smoothed this is tennis
# frame203 predicts tennis smoothed this is tennis
# frame204 predicts tennis smoothed this is tennis
# frame205 predicts tennis smoothed this is tennis
# frame206 predicts tennis smoothed this is tennis
# frame207 predicts tennis smoothed this is tennis
# frame208 predicts tennis smoothed this is tennis
# frame209 predicts tennis smoothed this is tennis
# frame210 predicts tennis smoothed this is tennis
# frame211 predicts tennis smoothed this is tennis
# frame212 predicts tennis smoothed this is tennis
# frame213 predicts tennis smoothed this is tennis
# frame214 predicts tennis smoothed this is tennis
# frame215 predicts tennis smoothed this is tennis
# frame216 predicts tennis smoothed this is tennis
# frame217 predicts tennis smoothed this is tennis
# frame218 predicts tennis smoothed this is tennis
# frame219 predicts tennis smoothed this is tennis
# frame220 predicts tennis smoothed this is tennis
# frame221 predicts tennis smoothed this is tennis
# frame222 predicts tennis smoothed this is tennis
# frame223 predicts tennis smoothed this is tennis
# frame224 predicts tennis smoothed this is tennis
